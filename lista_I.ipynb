# %% [markdown]
# 1. Faça um Programa que peça um número e então mostre a mensagem: O número informado foi [número].

# %%
del print
numero = int(input("Digite um número: "))
print("O número informado foi: ", numero) # acertei
# Out:
# Digite um número: 9
# O número informado foi:  9

# %% [markdown]
# 2. Faça um Programa que peça dois números e imprima a soma.

# %%
num1 = int(input("Digite um número: "))
num2 = int(input("Digite o segundo número: " ))
print(num1 + num2) # acertei
# Out:
# Digite um número: 8
# Digite o segundo número: 9
# 17

# %% [markdown]
# 3. Faça um Programa que peça as 4 notas bimestrais e mostre a média.

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
nota4 = float(input("Digite a quarta nota: "))
média = (nota1 + nota2 + nota3 + nota4)/4
print("Sua média é: ", média)
# Out:
# Digite a primeira nota: 8
# Digite a segunda nota: 7.5
# Digite a terceira nota: 9
# Digite a quarta nota: 10
# Sua média é 8.625

# %% [markdown]
# 4. Faça um Programa que converta metros para centímetros.

# %%
metros = float(input("Converta metros para cm: "))
centimetros = metros * 100
print("A conversão é:", centimetros)
# Out:
# Converta metros para cm: 9
# A conversão é: 900.0

# %% [markdown]
# 5. Faça um Programa que peça o raio de um círculo, calcule e mostre sua área

# %%
raio = float(input("Informe seu raio "))
área = 3.14 * raio ** 2
print ("A Área é: ", área)
# Out:
# Informe seu raio 6
# A Área é:  113.04

# %% [markdown]
# 6. Faça um Programa que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

# %%
lado = float(input("Informe um dos lados do quadrado: "))
area = lado * lado
print("O resultado da área é:", area)
dobro = area * 2
print("O dobro da área é: ", dobro)
# Out:
# Informe um dos lados do quadrado: 8
# O resultado da área é: 64.0
# O dobro da área é:  128.0

# %% [markdown]
# 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganhaPorHora = float(input("Quanto você ganha por hora? "))
numDeHoras = float(input("Quantas horas você trabalha por mês? "))
salario = ganhaPorHora * numDeHoras
print("Seu salário é: ", int(salario))
# Out:
# Quanto você ganha por hora? 30
# Quantas horas você trabalha por mês? 160
# Seu salário é:  4800

# %% [markdown]
# 8. Faça um Programa que peça a temperatura em graus Farenheit, transforme e mostre a temperatura em graus Celsius. C = (5 * (F-32) / 9).

# %%
grausFarenheit = float(input("Informe a temperatura em graus Farenheit: "))
grausCelsius = C = (5 *(grausFarenheit-32) / 9)
print("A tranformação de Farebheit para Celsius é:", grausCelsius)
# Out:
# Informe a temperatura em graus Farenheit: 100
# A tranformação de Farebheit para Celsius é: 37.77777777777778

# %% [markdown]
# 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Farenheit.

# %%
celsius = float(input("Digite a temperatura em Celsius: "))
farenheit = celsius * 9/5 + 32
print("De celsius para Farenheit é: ", farenheit)
# Out:
# Digite a temperatura em Celsius: 32
# De celsius para Farenheit é:  89.6

# %% [markdown]
# 10. Elaborar um algoritmo que efetue a apresentação do valor da conversão em real (R$) de um valor lido em dólar (US$). O algoritmo deverá solicitar o valor da cotação do dólar e também a quantidade de dólares disponíveis com o usuário.

# %%
quantidade = float(input("Quantidade de dólares disponíveis: "))
cotação = float(input("Valor da cotação? "))
conversao = quantidade * cotação
print("O valor em real é: ", conversao)
# Out:
# Quantidade de dólares disponíveis: 14
# Valor da cotação? 5.80
# O valor em real é:  81.2

# %% [markdown]
# 11. Faça um algoritmo que receba um valor que foi depositado e exiba o valor com rendimento após um mês. Considere fixo o juro da poupança em 0,70% a. m.

# %%
valorDepositado = float(input("Insira o valor depositado: "))
valorDepois = valorDepositado * (1 + 0.007)
print("O valor após um mês será de: ", valorDepois)
# Out:
# Insira o valor depositado: 1000
# O valor após um mês será de:  1006.9999999999999

# %% [markdown]
# 12. A Loja Mamão com Açúcar está vendendo seus produtos em 5 (cinco) prestações sem juros. Faça um algoritmo que receba um valor de uma compra e mostre o valor das prestações.

# %%
valor = float(input("Informe o valor da sua compra: "))
prestacoes = valor/5
print ("O valor das suas prestações será de: ", prestacoes)
# Out:
# Informe o valor da sua compra: 1000
# O valor das suas prestações será de:  200.0

# %% [markdown]
# 13. Faça um algoritmo que receba o preço de custo de um produto e mostre o valor de venda. Sabe-se que o preço de custo receberá um acréscimo de acordo com um percentual informado pelo usuário.

# %%
custo = float(input("Informe o valor do custo do produto: "))
custoAcrescimo = float(input("Informe o percentual de acréscimo: "))
valorVenda = custo * (1 + custoAcrescimo /100)
print(valorVenda)
# Out:
# Informe o valor do custo do produto: 100
# Informe o percentual de acréscimo: 20
# 120.0

# %% [markdown]
# 14. Escrever um algoritmo para determinar o consumo médio de um automóvel sendo fornecida a distância total percorrida pelo automóvel e o total de combustível gasto.

# %%
distancia = float(input('Informe a distância total percorrida (km): '))
combustivel = float(input('Informe o total de combistível gasto (litros): '))
consumoMedio = distancia / combustivel
print(consumoMedio)
# Out:
# Informe a distância total percorrida (km): 700
# Informe o total de combistível gasto (litros): 50
# 14.0

# %% [markdown]
# 15. Escreva um programa que leia três números inteiros e positivos (A, B, C) e calcule a seguinte expressão:

# %%
a = int(input("Informe o primeiro número: "))
b = int(input("Informe o segundo número: "))
c = int(input("Informe o terceiro número: "))

r = (a + b) ** 2
s = (b + c) ** 2

d = (r + s) /2

print("O valor da expressão é: ", d)
# Out:
# Informe o primeiro número: 2
# Informe o segundo número: 3
# Informe o terceiro número: 4
# O valor da expressão é:  37.0

# %% [markdown]
# 16. Escrever um algoritmo que leia o nome de um vendedor, o seu salário fixo e o total de vendas efetuadas por ele no mês (em dinheiro). Sabendo que este vendedor ganha 15% de comissão sobre suas vendas efetuadas, informar o seu nome, o salário fixo e salário no final do mês.

# %%
nome = (input("Informe seu nome: "))
salarioFixo = float(input("Informe seu salário fixo (R$): "))
vendas = float(input("Infome o total de vendas: "))
comissao = vendas * 0.15
salarioFinal = salarioFixo + comissao
print("Seu nome é: ", nome)
print("Seu salário fixo é: ", salarioFixo)
print("Seu salário final é de: ", salarioFinal)
# Out:
# Informe seu nome: lívia
# Informe seu salário fixo (R$): 10000
# Infome o total de vendas: 20000
# Seu nome é:  lívia
# Seu salário fixo é:  10000.0
# Seu salário final é de:  13000.0

# %% [markdown]
# 17. Faça um Programa que peça 2 números inteiros e um número real. Calcule e mostre:
#
# · o produto do dobro do primeiro com metade do segundo .
#
# · a soma do triplo do primeiro com o terceiro.
#
# · o terceiro elevado ao cubo.

# %%
numInt1 = int(input('Informe um número inteiro: '))
numInt2 = int(input("informe um número inteiro: "))
numReal = float(input("Informe um número real: "))

resultado1 = (numInt1 * 2) * (numInt2/2)
resultado2 = (numInt1 * 3) + numReal
resultado3 = numReal ** 3

print(resultado1)
print(resultado2)
print(resultado3)
# Out:
# Informe um número inteiro: 4
# informe um número inteiro: 6
# Informe um número real: 2.5
# 24.0
# 14.5
# 15.625

# %% [markdown]
# 18. Tendo como dados de entrada a altura de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula: (72.7*altura) – 58.

# %%
altura = float(input("Informe sua altura: "))
peso = (72.7*altura) - 58
print(peso)
# Out:
# Informe sua altura: 1.56
# 55.412000000000006

# %% [markdown]
# 19. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em MBps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).

# %%
tamanho = float(input("Informe o tamanho do arquivo para download em MB: "))
velocidade = float(input("Informe a velocidade do link de internet em MBps: "))
velocidade_segundos = tamanho / velocidade
velocidade_minutos = velocidade_segundos / 60
print("O tempo aproximado de download em minutos é: ", velocidade_minutos)
# Out:
# Informe o tamanho do arquivo para download em MB: 5000
# Informe a velocidade do link de internet em MBps: 200
# O tempo aproximado de download em minutos é:  0.4166666666666667

# %% [markdown]
# 20. Ler dois valores para as variáveis A e B, e efetuar as trocas dos valores de forma que a variável A passe a possuir o valor da variável B e a variável B passe a possuir o valor da variável A. Apresentar os valores trocados.

# %%
a = float(input("informe a variável A: "))
b = float(input("Informe a variável B: "))

temporaria = a
a = b
b = temporaria
print("A variável A é:",a,"A variável B é: ",b)
# Out:
# informe a variável A: 2
# Informe a variável B: 4
# A variável A é: 4.0 A variável B é:  2.0

# %% [markdown]
# 21. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato, faça um programa que nos dê:
#
# a) salário bruto.
#
# b) quanto pagou ao INSS.
#
# c) quanto pagou ao sindicato.
#
# d) o salário líquido.
#
# e) calcule os descontos e o salário líquido, conforme a tabela abaixo:
#
# Salário Bruto : R$
#
# IR (11%) : R$
#
# INSS (8%) : R$
#
# Sindicato ( 5%) : R$
#
# Salário Liquido : R$
#
# Obs.: Salário Bruto - Descontos = Salário Líquido.

# %%
ganhaPorHora = float(input("Informe quanto você ganha por hora: "))
horasTrabalhadas = float(input("Informe quantas horas você trabalha no mês: "))
salarioBruto = ganhaPorHora * horasTrabalhadas
impostoRenda = salarioBruto * 0.11
inss = salarioBruto * 0.08
sindicato = salarioBruto * 0.05
salarioLiquido = salarioBruto - (impostoRenda + inss + sindicato)

print("Ganha por hora: ", ganhaPorHora)
print("Horas trabalhadas: ", horasTrabalhadas)
print("Salário bruto: ", salarioBruto)
print("Imposto de renda:", impostoRenda)
print("Inss: ", inss)
print("Sindicato: ", sindicato)
print("Salário líquido: ", salarioLiquido)
# Out:
# Informe quanto você ganha por hora: 20
# Informe quantas horas você trabalha no mês: 60
# Ganha por hora:  20.0
# Horas trabalhadas:  60.0
# Salário bruto:  1200.0
# Imposto de renda: 132.0
# Inss:  96.0
# Sindicato:  60.0
# Salário líquido:  912.0
